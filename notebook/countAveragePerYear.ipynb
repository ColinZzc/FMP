# %%
year=2018
sql = f'''
create table AVG{year} as

        SELECT
            '{year}01'             "MONTH",
            AVG("A1"."AVG_PM25") "PM25",
            AVG("A1"."AVG_PM10") "PM10",
            AVG("A1"."AVG_SO2")  "SO2",
            AVG("A1"."AVG_NO2")  "NO2",
            AVG("A1"."AVG_CO")   "CO",
            AVG("A1"."AVG_O3")   "O3"
        FROM
            "COLIN"."AVG{year}01" "A1"
        GROUP BY
            '{year}01'

            union

        SELECT
            '{year}02'             "MONTH",
            AVG("A1"."AVG_PM25") "PM25",
            AVG("A1"."AVG_PM10") "PM10",
            AVG("A1"."AVG_SO2")  "SO2",
            AVG("A1"."AVG_NO2")  "NO2",
            AVG("A1"."AVG_CO")   "CO",
            AVG("A1"."AVG_O3")   "O3"
        FROM
            "COLIN"."AVG{year}02" "A1"
        GROUP BY
            '{year}02'

            union

        SELECT
            '{year}03'             "MONTH",
            AVG("A1"."AVG_PM25") "PM25",
            AVG("A1"."AVG_PM10") "PM10",
            AVG("A1"."AVG_SO2")  "SO2",
            AVG("A1"."AVG_NO2")  "NO2",
            AVG("A1"."AVG_CO")   "CO",
            AVG("A1"."AVG_O3")   "O3"
        FROM
            "COLIN"."AVG{year}03" "A1"
        GROUP BY
            '{year}03'

            union

        SELECT
            '{year}04'             "MONTH",
            AVG("A1"."AVG_PM25") "PM25",
            AVG("A1"."AVG_PM10") "PM10",
            AVG("A1"."AVG_SO2")  "SO2",
            AVG("A1"."AVG_NO2")  "NO2",
            AVG("A1"."AVG_CO")   "CO",
            AVG("A1"."AVG_O3")   "O3"
        FROM
            "COLIN"."AVG{year}04" "A1"
        GROUP BY
            '{year}04'

            union

        SELECT
            '{year}05'             "MONTH",
            AVG("A1"."AVG_PM25") "PM25",
            AVG("A1"."AVG_PM10") "PM10",
            AVG("A1"."AVG_SO2")  "SO2",
            AVG("A1"."AVG_NO2")  "NO2",
            AVG("A1"."AVG_CO")   "CO",
            AVG("A1"."AVG_O3")   "O3"
        FROM
            "COLIN"."AVG{year}05" "A1"
        GROUP BY
            '{year}05'

            union

        SELECT
            '{year}06'             "MONTH",
            AVG("A1"."AVG_PM25") "PM25",
            AVG("A1"."AVG_PM10") "PM10",
            AVG("A1"."AVG_SO2")  "SO2",
            AVG("A1"."AVG_NO2")  "NO2",
            AVG("A1"."AVG_CO")   "CO",
            AVG("A1"."AVG_O3")   "O3"
        FROM
            "COLIN"."AVG{year}06" "A1"
        GROUP BY
            '{year}06'

            union

        SELECT
            '{year}07'             "MONTH",
            AVG("A1"."AVG_PM25") "PM25",
            AVG("A1"."AVG_PM10") "PM10",
            AVG("A1"."AVG_SO2")  "SO2",
            AVG("A1"."AVG_NO2")  "NO2",
            AVG("A1"."AVG_CO")   "CO",
            AVG("A1"."AVG_O3")   "O3"
        FROM
            "COLIN"."AVG{year}07" "A1"
        GROUP BY
            '{year}07'

            union

        SELECT
            '{year}08'             "MONTH",
            AVG("A1"."AVG_PM25") "PM25",
            AVG("A1"."AVG_PM10") "PM10",
            AVG("A1"."AVG_SO2")  "SO2",
            AVG("A1"."AVG_NO2")  "NO2",
            AVG("A1"."AVG_CO")   "CO",
            AVG("A1"."AVG_O3")   "O3"
        FROM
            "COLIN"."AVG{year}08" "A1"
        GROUP BY
            '{year}08'

            union

        SELECT
            '{year}09'             "MONTH",
            AVG("A1"."AVG_PM25") "PM25",
            AVG("A1"."AVG_PM10") "PM10",
            AVG("A1"."AVG_SO2")  "SO2",
            AVG("A1"."AVG_NO2")  "NO2",
            AVG("A1"."AVG_CO")   "CO",
            AVG("A1"."AVG_O3")   "O3"
        FROM
            "COLIN"."AVG{year}09" "A1"
        GROUP BY
            '{year}09'

            union

        SELECT
            '{year}10'             "MONTH",
            AVG("A1"."AVG_PM25") "PM25",
            AVG("A1"."AVG_PM10") "PM10",
            AVG("A1"."AVG_SO2")  "SO2",
            AVG("A1"."AVG_NO2")  "NO2",
            AVG("A1"."AVG_CO")   "CO",
            AVG("A1"."AVG_O3")   "O3"
        FROM
            "COLIN"."AVG{year}10" "A1"
        GROUP BY
            '{year}10'

            union

        SELECT
            '{year}11'             "MONTH",
            AVG("A1"."AVG_PM25") "PM25",
            AVG("A1"."AVG_PM10") "PM10",
            AVG("A1"."AVG_SO2")  "SO2",
            AVG("A1"."AVG_NO2")  "NO2",
            AVG("A1"."AVG_CO")   "CO",
            AVG("A1"."AVG_O3")   "O3"
        FROM
            "COLIN"."AVG{year}11" "A1"
        GROUP BY
            '{year}11'

            union

        SELECT
            '{year}12'             "MONTH",
            AVG("A1"."AVG_PM25") "PM25",
            AVG("A1"."AVG_PM10") "PM10",
            AVG("A1"."AVG_SO2")  "SO2",
            AVG("A1"."AVG_NO2")  "NO2",
            AVG("A1"."AVG_CO")   "CO",
            AVG("A1"."AVG_O3")   "O3"
        FROM
            "COLIN"."AVG{year}12" "A1"
        GROUP BY
            '{year}12'

'''
print(sql)
# Out:
# create table AVG2018 as
#
#         SELECT
#             '201801'             "MONTH",
#             AVG("A1"."AVG_PM25") "PM25",
#             AVG("A1"."AVG_PM10") "PM10",
#             AVG("A1"."AVG_SO2")  "SO2",
#             AVG("A1"."AVG_NO2")  "NO2",
#             AVG("A1"."AVG_CO")   "CO",
#             AVG("A1"."AVG_O3")   "O3"
#         FROM
#             "COLIN"."AVG201801" "A1"
#         GROUP BY
#             '201801'
#
#             union
#
#         SELECT
#             '201802'             "MONTH",
#             AVG("A1"."AVG_PM25") "PM25",
#             AVG("A1"."AVG_PM10") "PM10",
#             AVG("A1"."AVG_SO2")  "SO2",
#             AVG("A1"."AVG_NO2")  "NO2",
#             AVG("A1"."AVG_CO")   "CO",
#             AVG("A1"."AVG_O3")   "O3"
#         FROM
#             "COLIN"."AVG201802" "A1"
#         GROUP BY
#             '201802'
#
#             union
#
#         SELECT
#             '201803'             "MONTH",
#             AVG("A1"."AVG_PM25") "PM25",
#             AVG("A1"."AVG_PM10") "PM10",
#             AVG("A1"."AVG_SO2")  "SO2",
#             AVG("A1"."AVG_NO2")  "NO2",
#             AVG("A1"."AVG_CO")   "CO",
#             AVG("A1"."AVG_O3")   "O3"
#         FROM
#             "COLIN"."AVG201803" "A1"
#         GROUP BY
#             '201803'
#
#             union
#
#         SELECT
#             '201804'             "MONTH",
#             AVG("A1"."AVG_PM25") "PM25",
#             AVG("A1"."AVG_PM10") "PM10",
#             AVG("A1"."AVG_SO2")  "SO2",
#             AVG("A1"."AVG_NO2")  "NO2",
#             AVG("A1"."AVG_CO")   "CO",
#             AVG("A1"."AVG_O3")   "O3"
#         FROM
#             "COLIN"."AVG201804" "A1"
#         GROUP BY
#             '201804'
#
#             union
#
#         SELECT
#             '201805'             "MONTH",
#             AVG("A1"."AVG_PM25") "PM25",
#             AVG("A1"."AVG_PM10") "PM10",
#             AVG("A1"."AVG_SO2")  "SO2",
#             AVG("A1"."AVG_NO2")  "NO2",
#             AVG("A1"."AVG_CO")   "CO",
#             AVG("A1"."AVG_O3")   "O3"
#         FROM
#             "COLIN"."AVG201805" "A1"
#         GROUP BY
#             '201805'
#
#             union
#
#         SELECT
#             '201806'             "MONTH",
#             AVG("A1"."AVG_PM25") "PM25",
#             AVG("A1"."AVG_PM10") "PM10",
#             AVG("A1"."AVG_SO2")  "SO2",
#             AVG("A1"."AVG_NO2")  "NO2",
#             AVG("A1"."AVG_CO")   "CO",
#             AVG("A1"."AVG_O3")   "O3"
#         FROM
#             "COLIN"."AVG201806" "A1"
#         GROUP BY
#             '201806'
#
#             union
#
#         SELECT
#             '201807'             "MONTH",
#             AVG("A1"."AVG_PM25") "PM25",
#             AVG("A1"."AVG_PM10") "PM10",
#             AVG("A1"."AVG_SO2")  "SO2",
#             AVG("A1"."AVG_NO2")  "NO2",
#             AVG("A1"."AVG_CO")   "CO",
#             AVG("A1"."AVG_O3")   "O3"
#         FROM
#             "COLIN"."AVG201807" "A1"
#         GROUP BY
#             '201807'
#
#             union
#
#         SELECT
#             '201808'             "MONTH",
#             AVG("A1"."AVG_PM25") "PM25",
#             AVG("A1"."AVG_PM10") "PM10",
#             AVG("A1"."AVG_SO2")  "SO2",
#             AVG("A1"."AVG_NO2")  "NO2",
#             AVG("A1"."AVG_CO")   "CO",
#             AVG("A1"."AVG_O3")   "O3"
#         FROM
#             "COLIN"."AVG201808" "A1"
#         GROUP BY
#             '201808'
#
#             union
#
#         SELECT
#             '201809'             "MONTH",
#             AVG("A1"."AVG_PM25") "PM25",
#             AVG("A1"."AVG_PM10") "PM10",
#             AVG("A1"."AVG_SO2")  "SO2",
#             AVG("A1"."AVG_NO2")  "NO2",
#             AVG("A1"."AVG_CO")   "CO",
#             AVG("A1"."AVG_O3")   "O3"
#         FROM
#             "COLIN"."AVG201809" "A1"
#         GROUP BY
#             '201809'
#
#             union
#
#         SELECT
#             '201810'             "MONTH",
#             AVG("A1"."AVG_PM25") "PM25",
#             AVG("A1"."AVG_PM10") "PM10",
#             AVG("A1"."AVG_SO2")  "SO2",
#             AVG("A1"."AVG_NO2")  "NO2",
#             AVG("A1"."AVG_CO")   "CO",
#             AVG("A1"."AVG_O3")   "O3"
#         FROM
#             "COLIN"."AVG201810" "A1"
#         GROUP BY
#             '201810'
#
#             union
#
#         SELECT
#             '201811'             "MONTH",
#             AVG("A1"."AVG_PM25") "PM25",
#             AVG("A1"."AVG_PM10") "PM10",
#             AVG("A1"."AVG_SO2")  "SO2",
#             AVG("A1"."AVG_NO2")  "NO2",
#             AVG("A1"."AVG_CO")   "CO",
#             AVG("A1"."AVG_O3")   "O3"
#         FROM
#             "COLIN"."AVG201811" "A1"
#         GROUP BY
#             '201811'
#
#             union
#
#         SELECT
#             '201812'             "MONTH",
#             AVG("A1"."AVG_PM25") "PM25",
#             AVG("A1"."AVG_PM10") "PM10",
#             AVG("A1"."AVG_SO2")  "SO2",
#             AVG("A1"."AVG_NO2")  "NO2",
#             AVG("A1"."AVG_CO")   "CO",
#             AVG("A1"."AVG_O3")   "O3"
#         FROM
#             "COLIN"."AVG201812" "A1"
#         GROUP BY
#             '201812'

# %%
pwd
# Out:
# 'C:\\Users\\colin\\Downloads\\ChinaVis\\ChinaVis'
